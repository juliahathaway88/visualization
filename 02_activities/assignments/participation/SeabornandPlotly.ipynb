# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(data=tips, # choose our dataset
 x='total_bill', # define our x variable
 y='tip') # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style('whitegrid')

# %%
tipgraph = sns.lineplot(data=tips,
 x='total_bill',
 y='tip')
tipgraph.set(title='Tips vs. Total Bill',
 xlabel='Total Bill ($)',
 ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
fig = plt.subplots(figsize=(10, 3))

# %%
tipgraph = sns.lineplot(data=tips,
 x='total_bill',
 y='tip',
 color = 'hotpink',
 linestyle = '--',
 linewidth = 3,
 marker = 'o',
 markerfacecolor = 'indigo')

# %%
tipgraph = sns.scatterplot(data=tips, x='total_bill',
 y='tip’, style = "time", hue =
 'day’, palette = ['purple’,
 'hotpink', 'deepskyblue’,
 'yellowgreen'])
tipgraph.set(title='Tips vs. Total Bill',
 xlabel='Total Bill ($)',
 ylabel='Tip Amount ($)')
# Out:
#   Cell In[10], line 2
#     y='tip’, style = "time", hue =
#       ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
sns.pairplot(
 data = tips,
 hue = 'day')

# %%
daysplot = sns.relplot(
 data=tips,
 x="total_bill",
 y="tip",
 hue="sex",
 col="day",
 kind="scatter",
 col_wrap=2)

# %%
import plotly.graph_objects as go # 'go' is 'graph objects’
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
graph = go.Figure()

# %%
graph.add_trace(go.Bar(x=x1, y=y1))

# %%
graph.update_layout(
 title="Pirate Scores",
 xaxis_title="Pirates",
 yaxis_title="Score")

# %%
graph.write_html("../../folders/pirategraph.html")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 graph.write_html("../../folders/pirategraph.html")
#
# File c:\Users\jmaha\Documents\DSI\visualization\visualization-env\Lib\site-packages\plotly\basedatatypes.py:3712, in BaseFigure.write_html(self, *args, **kwargs)
#    3609 """
#    3610 Write a figure to an HTML file representation
#    3611
#    (...)   3708 None
#    3709 """
#    3710 import plotly.io as pio
# -> 3712 return pio.write_html(self, *args, **kwargs)
#
# File c:\Users\jmaha\Documents\DSI\visualization\visualization-env\Lib\site-packages\plotly\io\_html.py:503, in write_html(fig, file, config, auto_play, include_plotlyjs, include_mathjax, post_script, full_html, animation_opts, validate, default_width, default_height, auto_open, div_id)
#     500 # Write HTML string
#     501 if path is not None:
#     502     # To use a different file encoding, pass a file descriptor
# --> 503     path.write_text(html_str, "utf-8")
#     504 else:
#     505     file.write(html_str)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.13-windows-x86_64-none\Lib\pathlib.py:1078, in Path.write_text(self, data, encoding, errors, newline)
#    1075     raise TypeError('data must be str, not %s' %
#    1076                     data.__class__.__name__)
#    1077 encoding = io.text_encoding(encoding)
# -> 1078 with self.open(mode='w', encoding=encoding, errors=errors, newline=newline) as f:
#    1079     return f.write(data)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.13-windows-x86_64-none\Lib\pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\..\\folders\\pirategraph.html'

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers', # we want points for a scatter plot
 marker=dict(
 size=15, # point size
 color='hotpink', # point colour
 opacity=1, # point transparency/alpha
 line=dict(width=5, color='purple') # point outline
 )))
graph.update_layout(
 title='Interactive Pirate Plot',
 xaxis_title='Pirates',
 yaxis_title='Scores',
 width=500, height=500)
